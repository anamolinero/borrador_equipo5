# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/Usuario/Documents/Adalab49/Módulo 3/Proyecto_módulo 3/borrador_equipo5/hr_raw_data.csv", index_col=0)
df.head()
# Out:
#   age attrition businesstravel    dailyrate                department  \
# 0  51        No            NaN  2015.722222                       NaN
# 1  52        No            NaN  2063.388889                       NaN
# 2  42        No  travel_rarely  1984.253968   Research & Development
# 3  47        No  travel_rarely  1771.404762                       NaN
# 4  46        No            NaN  1582.771346                       NaN
#
#    distancefromhome  education    educationfield  employeecount  \
# 0                 6          3               NaN              1
# 1                 1          4     Life Sciences              1
# 2                 4          2  Technical Degree              1
# 3                 2          4           Medical              1
# 4                 3          3  Technical Degree              1
#
#    employeenumber  ...  yearsatcompany  yearsincurrentrole  \
# 0               1  ...              20                 NaN
# ...

# %%
pd.set_option('display.max_columns', None) #para ver todas las columnas con scroll en el dataframe

# %%
df.tail()
# Out:
#       employeenumber  age attrition businesstravel  dailyrate department  \
# 1673             824   43        No                    488.94
# 1674            1087   47        No                   1973.98
# 1675             528   29        No  travel_rarely     290.04
# 1676              76   47        No  travel_rarely    1032.49
# 1677             401   32        No                    556.26
#
#       distance_home  education educationfield  employeecount  \
# 1673             26          3        medical              1
# 1674             26          4                             1
# 1675             15          3                             1
# 1676              4          3  life sciences              1
# 1677              2          2  life sciences              1
#
#       env_satisfaction  gender hourlyrate  job_engagement  joblevel  \
# 1673                 2  Female                          4         1
# 1674                 4  Female                          3         5
# ...

# %%
True == 1
# Out:
# True

# %%
df.groupby("joblevel")["dailyrate"].mean()
# Out:
# joblevel
# 1     290.255735
# 2     556.116715
# 3    1032.634706
# 4    1583.905526
# 5    1972.613671
# Name: dailyrate, dtype: float64

# %%
mover = df.pop('employeenumber')  # Eliminar y guardar la columna
df.insert(0, 'employeenumber', mover)

# %%
df
# Out:
#       employeenumber age attrition businesstravel    dailyrate  \
# 0                  1  51        No            NaN  2015.722222
# 1                  2  52        No            NaN  2063.388889
# 2                  3  42        No  travel_rarely  1984.253968
# 3                  4  47        No  travel_rarely  1771.404762
# 4                  5  46        No            NaN  1582.771346
# ...              ...  ..       ...            ...          ...
# 1673             824  43        No            NaN   488.944444
# 1674            1087  47        No            NaN  1973.984127
# 1675             528  29        No  travel_rarely   290.035510
# 1676              76  47        No  travel_rarely  1032.487286
# 1677             401  32        No            NaN   556.256661
#
#                     department  distancefromhome  education    educationfield  \
# 0                          NaN                 6          3               NaN
# ...

# %%
df["age"].unique()
# Out:
# array(['51', '52', '42', '47', '46', '48', '59', '41', '56', '38', '55',
#        '40', '58', '35', '45', '33', '36', '34', 'forty-seven', '53',
#        '43', '60', '32', '37', '49', '39', '50', '44', '30',
#        'fifty-eight', '29', '31', '54', '57', '27', 'thirty-six', '28',
#        '26', 'fifty-five', '25', 'fifty-two', 'thirty-one', '24',
#        'thirty', '23', '22', '21', '20', 'twenty-six', '19',
#        'thirty-seven', '18', 'thirty-two', 'twenty-four'], dtype=object)

# %%
reemplazos={'forty-seven': 47, 'fifty-eight':58, 'thirty-six':36, 'fifty-five':55, 'fifty-two':52, 'thirty-one':31, 'thirty':30, 'twenty-six':26, 'thirty-seven':37, 'thirty-two':32, 'twenty-four':24}

# Reemplazar los valores usando el diccionario
df['age'] = df['age'].replace(reemplazos)

# %%
df['age']
# Out:
# 0       51
# 1       52
# 2       42
# 3       47
# 4       46
#         ..
# 1673    43
# 1674    47
# 1675    29
# 1676    47
# 1677    32
# Name: age, Length: 1678, dtype: object

# %%
df['age'] = df['age'].astype(int)

# %%
df['age']
# Out:
# 0       51
# 1       52
# 2       42
# 3       47
# 4       46
#         ..
# 1673    43
# 1674    47
# 1675    29
# 1676    47
# 1677    32
# Name: age, Length: 1678, dtype: int32

# %%
df["gender"].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df["gender"]
# Out:
# 0       0
# 1       0
# 2       0
# 3       1
# 4       1
#        ..
# 1673    1
# 1674    1
# 1675    0
# 1676    1
# 1677    1
# Name: gender, Length: 1678, dtype: int64

# %%
df["gender"] = df["gender"].replace({0: 'Male', 1: 'Female'})

# %%
df["gender"]
# Out:
# 0         Male
# 1         Male
# 2         Male
# 3       Female
# 4       Female
#          ...
# 1673    Female
# 1674    Female
# 1675      Male
# 1676    Female
# 1677    Female
# Name: gender, Length: 1678, dtype: object

# %%
df["datebirth"]
# Out:
# 0       1972
# 1       1971
# 2       1981
# 3       1976
# 4       1977
#         ...
# 1673    1980
# 1674    1976
# 1675    1994
# 1676    1976
# 1677    1991
# Name: datebirth, Length: 1678, dtype: int64

# %%
df["datebirth"].unique()
# Out:
# array([1972, 1971, 1981, 1976, 1977, 1975, 1964, 1982, 1967, 1985, 1968,
#        1983, 1965, 1988, 1978, 1990, 1987, 1989, 1970, 1980, 1963, 1991,
#        1986, 1974, 1984, 1973, 1979, 1993, 1994, 1992, 1969, 1966, 1996,
#        1995, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005],
#       dtype=int64)

# %%
df.head()
# Out:
#    employeenumber  age attrition businesstravel    dailyrate  \
# 0               1   51        No            NaN  2015.722222
# 1               2   52        No            NaN  2063.388889
# 2               3   42        No  travel_rarely  1984.253968
# 3               4   47        No  travel_rarely  1771.404762
# 4               5   46        No            NaN  1582.771346
#
#                  department  distancefromhome  education    educationfield  \
# 0                       NaN                 6          3               NaN
# 1                       NaN                 1          4     Life Sciences
# 2   Research & Development                  4          2  Technical Degree
# 3                       NaN                 2          4           Medical
# 4                       NaN                 3          3  Technical Degree
#
#    employeecount  environmentsatisfaction  gender  hourlyrate  jobinvolvement  \
# ...

# %%
df = df.rename(columns={'distancefromhome': 'distance_home', 'environmentsatisfaction' : 'env_satisfaction', 'jobinvolvement': 'job_engagement', 'numcompaniesworked': 'companies_worked', 'overtime': 'extra_hours', 'percentsalaryhike' : 'salary_increase_%', 'relationshipsatisfaction': 'relation_satisfaction', ' standardhours': 'work_hours', 'stockoptionlevel': 'stock_options', 'totalworkingyears' : 'work_experience',  'trainingtimeslastyear' : 'trainings_last_year', 'yearsatcompany': 'years_company', 'yearsincurrentrole': 'years_role', 'yearssincelastpromotion': 'years_last_promo', 'yearswithcurrmanager': 'years_curr_manager', 'sameasmonthlyincome': 'same_income', 'roledepartament': 'role_dept', 'numberchildren': 'num_children', 'remotework': 'remote'})

# %%
df.head()
# Out:
#    employeenumber  age attrition businesstravel    dailyrate  \
# 0               1   51        No            NaN  2015.722222
# 1               2   52        No            NaN  2063.388889
# 2               3   42        No  travel_rarely  1984.253968
# 3               4   47        No  travel_rarely  1771.404762
# 4               5   46        No            NaN  1582.771346
#
#                  department  distance_home  education    educationfield  \
# 0                       NaN              6          3               NaN
# 1                       NaN              1          4     Life Sciences
# 2   Research & Development               4          2  Technical Degree
# 3                       NaN              2          4           Medical
# 4                       NaN              3          3  Technical Degree
#
#    employeecount  env_satisfaction  gender  hourlyrate  job_engagement  \
# 0              1                 1    Male         NaN               3
# ...

# %%
df['dailyrate']=df['dailyrate'].round(2)
# variable para correr y sobreescribir df_decimales = df['dailyrate'].round(2)

# %%
df
# Out:
#       employeenumber  age attrition businesstravel  dailyrate  \
# 0                  1   51        No            NaN    2015.72
# 1                  2   52        No            NaN    2063.39
# 2                  3   42        No  travel_rarely    1984.25
# 3                  4   47        No  travel_rarely    1771.40
# 4                  5   46        No            NaN    1582.77
# ...              ...  ...       ...            ...        ...
# 1673             824   43        No            NaN     488.94
# 1674            1087   47        No            NaN    1973.98
# 1675             528   29        No  travel_rarely     290.04
# 1676              76   47        No  travel_rarely    1032.49
# 1677             401   32        No            NaN     556.26
#
#                     department  distance_home  education    educationfield  \
# 0                          NaN              6          3               NaN
# ...

# %%
#Hemos hecho este bucle para convertir todos los datos de las columnas en minusculas
# Lista de columnas a convertir en minúsculas
columnas_minus = ['department', 'educationfield', 'jobrole', 'maritalstatus', 'role_dept']
# Bucle solo para esas columnas
for columna in columnas_minus:
    df[columna] = df[columna].str.lower()

# %%
df['maritalstatus'].unique()
# Out:
# array([nan, 'married', 'divorced', 'single', 'marreid'], dtype=object)

# %%
for columna in df:
    print(f'La columna {columna} tiene estos valores únicos:')
    print(df[columna].unique())
    print('----------------------------\n----------------------------------')
# Out:
# La columna employeenumber tiene estos valores únicos:
# [   1    2    3 ... 1612 1613 1614]
# ----------------------------
# ----------------------------------
# La columna age tiene estos valores únicos:
# [51 52 42 47 46 48 59 41 56 38 55 40 58 35 45 33 36 34 53 43 60 32 37 49
#  39 50 44 30 29 31 54 57 27 28 26 25 24 23 22 21 20 19 18]
# ----------------------------
# ----------------------------------
# La columna attrition tiene estos valores únicos:
# ['No' 'Yes']
# ----------------------------
# ----------------------------------
# La columna businesstravel tiene estos valores únicos:
# [nan 'travel_rarely' 'travel_frequently' 'non-travel']
# ----------------------------
# ----------------------------------
# La columna dailyrate tiene estos valores únicos:
# [2015.72 2063.39 1984.25 1771.4  1582.77 1771.92 1032.49  556.26 1712.18
#  1973.98 2060.71 1382.75 1362.52 2016.55 1861.37 1985.7  1108.92 1728.38
# ...

# %%
df.fillna(value='', inplace=True) # Esto reemplaza NaN por None, que se convierte en NULL en MySQL.
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_74172\2722362597.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.fillna(value='', inplace=True) # Esto reemplaza NaN por None, que se convierte en NULL en MySQL.

# %%
df
# Out:
#       employeenumber  age attrition businesstravel  dailyrate  \
# 0                  1   51        No                   2015.72
# 1                  2   52        No                   2063.39
# 2                  3   42        No  travel_rarely    1984.25
# 3                  4   47        No  travel_rarely    1771.40
# 4                  5   46        No                   1582.77
# ...              ...  ...       ...            ...        ...
# 1673             824   43        No                    488.94
# 1674            1087   47        No                   1973.98
# 1675             528   29        No  travel_rarely     290.04
# 1676              76   47        No  travel_rarely    1032.49
# 1677             401   32        No                    556.26
#
#                     department  distance_home  education    educationfield  \
# 0                                           6          3
# 1                                           1          4     life sciences
# ...

# %%
df["remote"] = df["remote"].replace({"True": 'Yes'})

# %%
df["remote"].unique() # Tenemos que reemplazar el 1 por el Yes y el 0 por el False
# Out:
# array(['Yes', '1', 'False', '0'], dtype=object)

# %%
df
# Out:
#       employeenumber  age attrition businesstravel  dailyrate  \
# 0                  1   51        No                   2015.72
# 1                  2   52        No                   2063.39
# 2                  3   42        No  travel_rarely    1984.25
# 3                  4   47        No  travel_rarely    1771.40
# 4                  5   46        No                   1582.77
# ...              ...  ...       ...            ...        ...
# 1673             824   43        No                    488.94
# 1674            1087   47        No                   1973.98
# 1675             528   29        No  travel_rarely     290.04
# 1676              76   47        No  travel_rarely    1032.49
# 1677             401   32        No                    556.26
#
#                     department  distance_home  education    educationfield  \
# 0                                           6          3
# 1                                           1          4     life sciences
# ...

# %%
df.shape
# Out:
# (1678, 41)

# %%
df["distance_home"] = df["distance_home"].abs()

# %%
df["distance_home"] #Preguntar si nos quedamos con los valores absolutos??
# Out:
# 0        6
# 1        1
# 2        4
# 3        2
# 4        3
#         ..
# 1673    26
# 1674    26
# 1675    15
# 1676     4
# 1677     2
# Name: distance_home, Length: 1678, dtype: int64

# %%
df["maritalstatus"] = df["maritalstatus"].replace({"marreid": "married"}) # Aqui eliminamos los errores ortotipográficos

# %%
df["maritalstatus"].unique() #Hay valores únicos vacíos que los vamos a reemplazar por None
# Out:
# array(['', 'married', 'divorced', 'single'], dtype=object)

# %%
# Aqui tocaría ver si eliminamos o no los duplicados -- Si eliminaría los 64 duplicados y las columnas mounthly_in_come y sale_income
